# %%
# %load_ext autoreload
# %autoreload 2

# %%
import gymnasium as gym
from stable_baselines3 import DQN, PPO

# %%
env = gym.make("MountainCar-v0")
model = DQN("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000, progress_bar=True)
model.save('agents/dqn_mountaincar')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /Users/OAA/miniforge3/envs/DL/lib/python3.8/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1795     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 174      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1855     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00471  |
# |    n_updates        | 374      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1978     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000304 |
# |    n_updates        | 574      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2121     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000202 |
# |    n_updates        | 774      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2251     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.64e-05 |
# |    n_updates        | 974      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2320     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.41e-05 |
# |    n_updates        | 1174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2366     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.57e-05 |
# |    n_updates        | 1374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2407     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39e-05 |
# |    n_updates        | 1574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2430     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.72e-06 |
# |    n_updates        | 1774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2460     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.83e-06 |
# |    n_updates        | 1974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2495     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01e-06 |
# |    n_updates        | 2174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2532     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.77e-06 |
# |    n_updates        | 2374     |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
